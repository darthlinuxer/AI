# %% [markdown]
# # FastAPI

# %%
from enum import Enum
from fastapi import FastAPI
from pydantic import BaseModel
import logging
from fastapi import FastAPI, Request
from opentelemetry.instrumentation.fastapi import FastAPIInstrumentor
from otel_config import setup_tracing

app = FastAPI()
setup_tracing()

# Instrument FastAPI app
FastAPIInstrumentor.instrument_app(app)

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


class Category(Enum):
    TOOLS = "tools"
    CONSUMABLES = "consumables"
    
class Item(BaseModel):
    id: int
    name: str
    price: float
    category: Category
    count: int
    
items = {
    0: Item(id=0, name="hammer", price=10.0, category=Category.TOOLS, count=10),
    1: Item(id=1, name="screwdriver", price=5.0, category=Category.TOOLS, count=20),
    2: Item(id=2, name="saw", price=20.0, category=Category.TOOLS, count=5),
    3: Item(id=3, name="plastic bottle", price=0.5, category=Category.CONSUMABLES, count=100),
}

# %%
@app.get("/")
async def index() -> dict[str, dict[int,Item]]:
    logger.info("Simple get was called!")
    return {"items": items}

# %% [markdown]
# ## How to run your API ?

# %%
import uvicorn
import nest_asyncio

nest_asyncio.apply()

def run_server():
    try:
        uvicorn.run(app, host="127.0.0.1", port=8000, reload=False)
    except Exception as e:
        print(f"Error starting server: {e}")
    finally:
        print("Server stopped")


if __name__ == "__main__":
    run_server()
# Out:
# INFO:     Started server process [1329134]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:__main__:Simple get was called!
# INFO:     127.0.0.1:58692 - "GET / HTTP/1.1" 200 OK
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0x95943ba4040dcbb8c08b0e86abae59c5",
#         "span_id": "0xe620c57bd66ca3b2",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xfd6db4f1e2f3b6ee",
#     "start_time": "2024-05-14T14:40:01.873424Z",
#     "end_time": "2024-05-14T14:40:01.875215Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.status_code": 200,
#         "type": "http.response.start"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0x95943ba4040dcbb8c08b0e86abae59c5",
#         "span_id": "0xf95fc979b8cfeaf4",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xfd6db4f1e2f3b6ee",
#     "start_time": "2024-05-14T14:40:01.875408Z",
#     "end_time": "2024-05-14T14:40:01.876033Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "type": "http.response.body"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET /",
#     "context": {
#         "trace_id": "0x95943ba4040dcbb8c08b0e86abae59c5",
#         "span_id": "0xfd6db4f1e2f3b6ee",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.SERVER",
#     "parent_id": null,
#     "start_time": "2024-05-14T14:40:01.871700Z",
#     "end_time": "2024-05-14T14:40:01.876082Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.scheme": "http",
#         "http.host": "127.0.0.1:8000",
#         "net.host.port": 8000,
#         "http.flavor": "1.1",
#         "http.target": "/",
#         "http.url": "http://127.0.0.1:8000/",
#         "http.method": "GET",
#         "http.server_name": "127.0.0.1:8000",
#         "http.user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
#         "net.peer.ip": "127.0.0.1",
#         "net.peer.port": 58692,
#         "http.route": "/",
#         "http.status_code": 200
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0xc63b107c90eb4b79e6822fa787e2985f",
#         "span_id": "0xcc30db2b9b798f35",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xa34066e7ab089394",
#     "start_time": "2024-05-14T14:40:33.337488Z",
#     "end_time": "2024-05-14T14:40:33.338931Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.status_code": 200,
#         "type": "http.response.start"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0xc63b107c90eb4b79e6822fa787e2985f",
#         "span_id": "0x40feae40db3c2474",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xa34066e7ab089394",
#     "start_time": "2024-05-14T14:40:33.339075Z",
#     "end_time": "2024-05-14T14:40:33.339228Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "type": "http.response.body"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET /",
#     "context": {
#         "trace_id": "0xc63b107c90eb4b79e6822fa787e2985f",
#         "span_id": "0xa34066e7ab089394",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.SERVER",
#     "parent_id": null,
#     "start_time": "2024-05-14T14:40:33.336457Z",
#     "end_time": "2024-05-14T14:40:33.339242Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.scheme": "http",
#         "http.host": "127.0.0.1:8000",
#         "net.host.port": 8000,
#         "http.flavor": "1.1",
#         "http.target": "/",
#         "http.url": "http://127.0.0.1:8000/",
#         "http.method": "GET",
#         "http.server_name": "127.0.0.1:8000",
#         "http.user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
#         "net.peer.ip": "127.0.0.1",
#         "net.peer.port": 60878,
#         "http.route": "/",
#         "http.status_code": 200
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0x42d54e93ede478ffda5c7c8a50019dd8",
#         "span_id": "0x4b29f3d62d42fce0",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe6f833a85f81ecf3",
#     "start_time": "2024-05-14T14:40:34.670751Z",
#     "end_time": "2024-05-14T14:40:34.671470Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.status_code": 200,
#         "type": "http.response.start"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0x42d54e93ede478ffda5c7c8a50019dd8",
#         "span_id": "0xf9be4d79228cc359",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe6f833a85f81ecf3",
#     "start_time": "2024-05-14T14:40:34.671583Z",
#     "end_time": "2024-05-14T14:40:34.671669Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "type": "http.response.body"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET /",
#     "context": {
#         "trace_id": "0x42d54e93ede478ffda5c7c8a50019dd8",
#         "span_id": "0xe6f833a85f81ecf3",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.SERVER",
#     "parent_id": null,
#     "start_time": "2024-05-14T14:40:34.669743Z",
#     "end_time": "2024-05-14T14:40:34.671677Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.scheme": "http",
#         "http.host": "127.0.0.1:8000",
#         "net.host.port": 8000,
#         "http.flavor": "1.1",
#         "http.target": "/",
#         "http.url": "http://127.0.0.1:8000/",
#         "http.method": "GET",
#         "http.server_name": "127.0.0.1:8000",
#         "http.user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
#         "net.peer.ip": "127.0.0.1",
#         "net.peer.port": 60878,
#         "http.route": "/",
#         "http.status_code": 200
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0xad3b77063868fc3773fc65983530c34c",
#         "span_id": "0xd6f7bb503fdff3e4",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe7cd5de015d84ea5",
#     "start_time": "2024-05-14T14:40:35.569959Z",
#     "end_time": "2024-05-14T14:40:35.570996Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.status_code": 200,
#         "type": "http.response.start"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET / http send",
#     "context": {
#         "trace_id": "0xad3b77063868fc3773fc65983530c34c",
#         "span_id": "0xec1b82a2d0fd24d8",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe7cd5de015d84ea5",
#     "start_time": "2024-05-14T14:40:35.571109Z",
#     "end_time": "2024-05-14T14:40:35.571198Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "type": "http.response.body"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "GET /",
#     "context": {
#         "trace_id": "0xad3b77063868fc3773fc65983530c34c",
#         "span_id": "0xe7cd5de015d84ea5",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.SERVER",
#     "parent_id": null,
#     "start_time": "2024-05-14T14:40:35.568895Z",
#     "end_time": "2024-05-14T14:40:35.571207Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "http.scheme": "http",
#         "http.host": "127.0.0.1:8000",
#         "net.host.port": 8000,
#         "http.flavor": "1.1",
#         "http.target": "/",
#         "http.url": "http://127.0.0.1:8000/",
#         "http.method": "GET",
#         "http.server_name": "127.0.0.1:8000",
#         "http.user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
#         "net.peer.ip": "127.0.0.1",
#         "net.peer.port": 60878,
#         "http.route": "/",
#         "http.status_code": 200
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.24.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# INFO:__main__:Simple get was called!
# INFO:     127.0.0.1:60878 - "GET / HTTP/1.1" 200 OK
# INFO:__main__:Simple get was called!
# INFO:     127.0.0.1:60878 - "GET / HTTP/1.1" 200 OK
# INFO:__main__:Simple get was called!
# INFO:     127.0.0.1:60878 - "GET / HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1329134]
# Server stopped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      12         print("Server stopped")
#      15 if __name__ == "__main__":
# ---> 16     run_server()
#
# Cell In[13], line 8, in run_server()
#       6 def run_server():
#       7     try:
# ----> 8         uvicorn.run(app, host="127.0.0.1", port=8000, reload=False)
#       9     except Exception as e:
#      10         print(f"Error starting server: {e}")
#
# File ~/AI/lib/python3.10/site-packages/uvicorn/main.py:575, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     573     Multiprocess(config, target=server.run, sockets=[sock]).run()
#     574 else:
# --> 575     server.run()
#     576 if config.uds and os.path.exists(config.uds):
#     577     os.remove(config.uds)  # pragma: py-win32
#
# File ~/AI/lib/python3.10/site-packages/uvicorn/server.py:65, in Server.run(self, sockets)
#      63 def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64     self.config.setup_event_loop()
# ---> 65     return asyncio.run(self.serve(sockets=sockets))
#
# File ~/AI/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/AI/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/AI/lib/python3.10/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File /usr/lib/python3.10/asyncio/events.py:80, in Handle._run(self)
#      78 def _run(self):
#      79     try:
# ---> 80         self._context.run(self._callback, *self._args)
#      81     except (SystemExit, KeyboardInterrupt):
#      82         raise
#
# File /usr/lib/python3.10/asyncio/tasks.py:315, in Task.__wakeup(self, future)
#     307     self.__step(exc)
#     308 else:
#     309     # Don't pass the value of `future.result()` explicitly,
#     310     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     313     # instead of `__next__()`, which is slower for futures
#     314     # that return non-generator iterators from their `__iter__`.
# --> 315     self.__step()
#     316 self = None
#
# File /usr/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/AI/lib/python3.10/site-packages/uvicorn/server.py:68, in Server.serve(self, sockets)
#      67 async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68     with self.capture_signals():
#      69         await self._serve(sockets)
#
# File /usr/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~/AI/lib/python3.10/site-packages/uvicorn/server.py:328, in Server.capture_signals(self)
#     324 # If we did gracefully shut down due to a signal, try to
#     325 # trigger the expected behaviour now; multiple signals would be
#     326 # done LIFO, see https://stackoverflow.com/questions/48434964
#     327 for captured_signal in reversed(self._captured_signals):
# --> 328     signal.raise_signal(captured_signal)
#
# KeyboardInterrupt:
